# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadnazir2006/AI-SCRIPT-GENERATOR/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from inspect import indentsize
from google.colab import files
files.upload
import pandas as pd
df = pd.read_csv('pokemon_data.csv')
import re
#df.loc[df['Type 1']=='Fire']
#df.sort_values(['HP','Type 1'],ascending=[1,0])
#Making Changes to data set
"""print(df)

df['Total']=df['HP']+df['Sp. Atk']+df['Attack']+df['Defense']+df['Speed']+df['Sp. Def']
print(df.head(5))
df=df.drop(columns=['Total'])"""#dropping a column or columns
"""
#summing up through slicing
df['Total']=df.iloc[:,4:11].sum(axis=1)
df.head(5)
"""
"""#using .to_csv()
df.to_csv('pokemon_data.csv',index=False)
print(df)"""
"""
#using .to_excel
df.to_excel('pokemon_data.xlsx',index=True)
df"""

"""#Filtering Data
df.loc[(df['Type 1']=='Grass')&(df['Type 2']=='Poison')&(df['Attack']==50)]
"""

"""#filtering a specific word
#df.loc[df['Name'].str.contains('Mega')]

df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.IGNORECASE,regex=True)]


df.loc[df['Type 1']=='Fire','Type 1']='FLAME'
df
df.drop(df.columns[0:2],axis=1)"""

"""#changing conditionals
df.loc[df['Attack']>50,['Speed','Legendary']]='TEST VALUE'
df
df.loc[df['Attack']>50,['Speed','Legendary']]=[100,'TEST']
df"""

#Aggregate Stats (Group BY Function)
df.groupby(['Type 1']).mean(numeric_only=True).sort_values('Attack',ascending=False)
# Out:
#           Unnamed: 0.1  Unnamed: 0           #         HP      Attack  \
# Type 1
# Dragon      521.843750  521.843750  474.375000  83.312500  112.125000
# Fighting    400.444444  400.444444  363.851852  69.851852   96.777778
# Ground      392.312500  392.312500  356.281250  73.781250   95.750000
# Rock        431.840909  431.840909  392.727273  65.363636   92.863636
# Steel       486.296296  486.296296  442.851852  65.222222   92.703704
# Dark        507.387097  507.387097  461.354839  66.806452   88.387097
# Fire        360.942308  360.942308  327.403846  69.903846   84.769231
# Flying      746.500000  746.500000  677.750000  70.750000   78.750000
# Poison      278.285714  278.285714  251.785714  67.250000   74.678571
# Water       333.312500  333.312500  303.089286  72.062500   74.151786
# Ghost       536.281250  536.281250  486.500000  64.437500   73.781250
# Normal      351.581633  351.581633  319.173469  77.275510   73.469388
# ...
